# %% [markdown]
# ### Reservation Confirmation
#
# - **User:** Arsany
# - **Service:** New Car ID
# - **Date:** 13-04-2025 (Sunday)
# - **Time:** 9:00
# - **ID:** 11122121212
# - **Full Name:** RSANY RAFAFAF
